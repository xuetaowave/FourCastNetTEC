# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

# %%
# show train data
data_load = h5py.File('train/2010.h5')
data = data_load['fields']
data.shape
# Out:
# (336, 13, 128, 256)

# %%
plt.pcolor(data[0, 0])
plt.colorbar()
